# %% [markdown]
# DATA CLEANING

# %%
import pandas as pd
vl= pd.read_csv("laptopData.csv")

# %%
vl
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook   65.4
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
vl.info()
vl.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1273 non-null   float64
#  1   Company           1273 non-null   object
#  2   TypeName          1253 non-null   object
#  3   Inches            1220 non-null   object
#  4   ScreenResolution  1273 non-null   object
#  5   Cpu               1273 non-null   object
#  6   Ram               1259 non-null   object
#  7   Memory            1273 non-null   object
#  8   Gpu               1273 non-null   object
#  9   OpSys             1273 non-null   object
#  10  Weight            1259 non-null   object
#  11  Price             1273 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 122.3+ KB
#         Unnamed: 0          Price
# count  1273.000000    1273.000000
# mean    652.674784   59955.814073
# std     376.493027   37332.251005
# ...

# %%
vl.isnull().sum()
# Out:
# Unnamed: 0          30
# Company             30
# TypeName            50
# Inches              83
# ScreenResolution    30
# Cpu                 30
# Ram                 44
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              44
# Price               30
# dtype: int64

# %%
vl.size
# Out:
# 15636

# %%
vl.shape
# Out:
# (1303, 12)

# %%
cat = ['Company', 'TypeName', 'Cpu', 'Gpu', 'OpSys', 'ScreenResolution', 'Memory']

for col in cat:
    vl[col] = vl[col].fillna(vl[col].mode()[0])

# %%
vl = vl.drop("Unnamed: 0", axis=1)

# %%
vl
# Out:
#      Company            TypeName Inches  \
# 0      Apple           Ultrabook   13.3
# 1      Apple           Ultrabook   13.3
# 2         HP            Notebook   15.6
# 3      Apple           Ultrabook   15.4
# 4      Apple           Ultrabook   13.3
# ...      ...                 ...    ...
# 1298  Lenovo  2 in 1 Convertible     14
# 1299  Lenovo  2 in 1 Convertible   13.3
# 1300  Lenovo            Notebook   65.4
# 1301      HP            Notebook   15.6
# 1302    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
vl['Price'] = vl.groupby('Company')['Price'].transform(lambda x: x.fillna(x.median()))

# %%
vl
# Out:
#      Company            TypeName Inches  \
# 0      Apple           Ultrabook   13.3
# 1      Apple           Ultrabook   13.3
# 2         HP            Notebook   15.6
# 3      Apple           Ultrabook   15.4
# 4      Apple           Ultrabook   13.3
# ...      ...                 ...    ...
# 1298  Lenovo  2 in 1 Convertible     14
# 1299  Lenovo  2 in 1 Convertible   13.3
# 1300  Lenovo            Notebook   65.4
# 1301      HP            Notebook   15.6
# 1302    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
vl.dtypes
# Out:
# Company              object
# TypeName             object
# Inches               object
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price               float64
# dtype: object

# %%
vl["Ram"] = vl["Ram"].ffill().bfill()

# %%
vl["Ram"]=vl["Ram"].str.extract(r'(\d)')

# %%
vl["Weight"]=vl["Weight"].str .extract(r'(\d)')

# %%
vl.dtypes
# Out:
# Company              object
# TypeName             object
# Inches               object
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price               float64
# dtype: object

# %%
vl.rename(columns={'Weight':'Weight(KG)'},inplace=True)

# %%
vl['Inches']=pd.to_numeric(vl['Inches'],errors='coerce')

# %%
vl['Weight(KG)']=pd.to_numeric(vl['Weight(KG)'],errors='coerce')

# %%
vl['Ram']=pd.to_numeric(vl['Ram'],errors='coerce')

# %%
vl['Ram']=pd.to_numeric(vl['Ram'],errors='coerce')

# %%
vl.dtypes
# Out:
# Company              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                   int64
# Memory               object
# Gpu                  object
# OpSys                object
# Weight(KG)          float64
# Price               float64
# dtype: object

# %%
vl.isnull().sum()
# Out:
# Company              0
# TypeName             0
# Inches              84
# ScreenResolution     0
# Cpu                  0
# Ram                  0
# Memory               0
# Gpu                  0
# OpSys                0
# Weight(KG)          45
# Price                0
# dtype: int64

# %%
mean_inches = vl['Inches'].mean()
print(mean_inches)
vl['Inches']=vl['Inches'].fillna(mean_inches)
# Out:
# 15.412059064807218

# %%
vl
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    65.4
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
mean_inches = vl['Weight(KG)'].mean()
print(mean_inches)
vl['Weight(KG)']=vl['Weight(KG)'].fillna(mean_inches)
# Out:
# 1.6653418124006358

# %%
vl.rename(columns={'Ram':'Ram'},inplace=True)

# %%
vl['Weight(KG)']=pd.to_numeric(vl['Weight(KG)'],errors='coerce')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.boxplot(vl[['Ram', 'Weight(KG)','Inches']])
plt.xticks([1,2,3,],['Ram', 'Weight(KG)','Inches'])
plt.ylabel('Values')
plt.title('Box Plot')
plt.show()

# %%
q3 = vl['Inches'].quantile(0.75)
q1 = vl['Inches'].quantile(0.25)
iqr = q3 - q1
lower_bound=q1-1.5*iqr
upper_bound=q3+1.5*iqr

med_val=vl['Inches'].median()

vl.loc[(vl['Inches']<lower_bound) | (vl['Inches']>upper_bound),'Inches']=round(med_val,0)

# %%
q3 = vl['Weight(KG)'].quantile(0.75)
q1 = vl['Weight(KG)'].quantile(0.25)
iqr = q3 - q1
lower_bound=q1-1.5*iqr
upper_bound=q3+1.5*iqr

med_val=vl['Weight(KG)'].median()

vl.loc[(vl['Weight(KG)']<lower_bound) | (vl['Weight(KG)']>upper_bound),'Weight(KG)']=round(med_val,0)

# %%
plt.boxplot(vl[['Ram', 'Weight(KG)','Inches']])
plt.xticks([1,2,3,],['Ram', 'Weight(KG)','Inches'])
plt.ylabel('Values')
plt.title('Box Plot')
plt.show()

# %%
vl
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    16.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %% [markdown]
# 2. EXPLORTORY DATA ANALY

# %% [markdown]
# UNI

# %%
sns.histplot(vl['Price'], bins=30,kde=True,color='green', edgecolor='black')
plt.title('Price Distribution')
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
plt.figure(figsize=(10, 4))
sns.countplot(x='Ram',data=vl,order=sorted(vl['Ram'].unique()),palette='viridis' )
plt.title('RAM Distribution (Countplot)', fontsize=14)
plt.xlabel('RAM (GB)')
plt.ylabel('Count') 
plt.show()

# %%
plt.figure(figsize=(10, 4))
sns.violinplot(x=vl['Inches'])
plt.title('Screen Size (Inches) Distribution (Violin Plot)')
plt.xlabel('Screen Size (Inches)')
plt.show()

# %%
print(vl[['Price', 'Ram', 'Inches']].describe())
# Out:
#                Price          Ram       Inches
# count    1303.000000  1303.000000  1303.000000
# mean    59678.214056     5.392172    15.171998
# std     36943.966098     2.730974     1.233227
# min      9270.720000     1.000000    12.000000
# 25%     32650.250400     4.000000    14.000000
# 50%     50669.280000     6.000000    15.600000
# 75%     78561.360000     8.000000    15.600000
# max    324954.720000     8.000000    17.300000

# %% [markdown]
# Bivariate Analysis

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(
    x='Ram',
    y='Price',
    data=vl,
    palette='Set2'  
)
plt.title('Price vs. RAM', fontsize=14)
plt.xlabel('RAM (GB)')
plt.ylabel('Price')
plt.show()

# %%
vl['Cpu_Brand'] = vl['Cpu'].apply(lambda x: x.split()[0])

plt.figure(figsize=(12, 6))
sns.boxplot(
    x='Cpu_Brand',
    y='Price',
    data=vl,
    palette='husl'  
)
plt.title('Price vs. CPU Brand', fontsize=14)
plt.xlabel('CPU Brand')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %%
vl
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    16.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
plt.figure(figsize=(15, 6))
sns.stripplot(
    x='Ram',
    y='Weight(KG)',
    data=vl,
    hue='Ram',           
    jitter=True,
    palette='Set2',     
    dodge=False          
)
plt.title('Weight by RAM Size (Stripplot)', fontsize=14)
plt.xlabel('RAM(GB)')
plt.ylabel('Weight(KG)')
plt.legend(title='RAM Size', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(12, 6))

sns.swarmplot(
    x='Gpu',
    y='Price',
    data=vl,
    palette='Set2'
)

plt.title("Price by GPU Brand (Swarm Plot)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# MULTIVARIEN

# %%
corr = vl[['Inches','Ram','Weight(KG)','Price']].corr()
sns.heatmap(corr, annot=True, cmap='RdPu')
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.pairplot(vl[['Inches', 'Ram', 'Weight(KG)', 'Price']], palette='husl')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='Ram', y='Price', hue='TypeName', size='Inches', data=vl, palette='pastel')
plt.title('Price vs RAM, colored by Laptop Type, sized by Screen Inches')
plt.show()

# %% [markdown]
# VISUALIZATION

# %%
#  Price distribution
plt.figure(figsize=(10, 5))
sns.histplot(vl['Price'], kde=True, color='skyblue')
plt.title('Distribution of Laptop Prices', fontsize=14)
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# RAM distribution
plt.figure(figsize=(10, 5))
sns.histplot(vl['Ram'], kde=True, color='lightgreen')
plt.title('Distribution of RAM Size', fontsize=14)
plt.xlabel('RAM (GB)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Box plots → Price by Company, Price by Type

# %%
#  Price by Company
plt.figure(figsize=(14, 6))
sns.boxplot(x='Company', y='Price', data=vl, palette='pastel')
plt.title('Price Distribution by Company', fontsize=14)
plt.xlabel('Company')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

#  Price by TypeName
plt.figure(figsize=(12, 6))
sns.boxplot(x='TypeName', y='Price', data=vl, palette='Set2')
plt.title('Price by Laptop Type', fontsize=14)
plt.xlabel('Laptop Type')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Ram', y='Price', data=vl, hue='TypeName', palette='husl')
plt.title('Price vs RAM by Laptop Type', fontsize=14)
plt.xlabel('RAM (GB)')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Inches', y='Weight(KG)', data=vl, hue='TypeName', palette='husl')
plt.title('Screen Size vs Weight by Laptop Type', fontsize=14)
plt.xlabel('Screen Size (Inches)')
plt.ylabel('Weight (kg)')
plt.show()

# %%
corr = vl[['Inches', 'Ram', 'Weight(KG)', 'Price']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='YlGnBu')
plt.title('Correlation Heatmap', fontsize=14)
plt.show()

# %% [markdown]
#  Trends, Preferences & Market Dynamics

# %%
plt.figure(figsize=(14, 6))
sns.boxplot(x='Company', y='Price', data=vl, palette='Set3')
plt.title('Price Distribution by Brand', fontsize=14)
plt.xticks(rotation=45)
plt.xlabel('Company')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(x='TypeName', y='Price', data=vl, palette='pastel')
plt.title('Price by Laptop Type', fontsize=14)
plt.xticks(rotation=45)
plt.xlabel('Laptop Type')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x='Inches', y='Weight(KG)', hue='TypeName', data=vl, palette='husl', s=100)
plt.title('Screen Size vs Weight by Laptop Type', fontsize=14)
plt.xlabel('Screen Size (Inches)')
plt.ylabel('Weight (kg)')
plt.show()

# %%
company_counts = vl['Company'].value_counts().head(10) 
plt.figure(figsize=(8, 8))
company_counts.plot(kind='pie', autopct='%1.1f%%', colors=sns.color_palette('Set2'))
plt.title('Market Share by Company (Top 10)', fontsize=14)
plt.ylabel('')
plt.show()

# %%
from scipy.stats import f_oneway
vl = vl.dropna(subset=['Company', 'Price'])

groups = vl.groupby('Company')['Price'].apply(list)

stat,p_value = f_oneway(*groups)

print("ANOVA Results:")
print(f"F-statistic: {stat:.2f}")
print(f"P-value: {p_value:.2f}")

if p_value < 0.05:
    print("reject the null hypothesis.")
else:
    print("fail to reject the null hypothesis.")
